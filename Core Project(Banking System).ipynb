# %% [markdown]
# <font color="RED"><h1><b>Banking System (with oops)</b></h1></font>

# %%
import getpass as g
class banking_system:
    def __init__(self):
        self.CN = []
        self.CM = []
        self.CA = []
        self.CB = []
        self.CP = []
    def bank(self):
        Bank_ID="7413"
        Bank_password="100200300"
        Employee_Name="Aayush"
        a=input("enter Bank ID : ")
        b=g.getpass("Enter Bank Password : ")
        c=input("Enter your Name : ")
        print()
        if a==Bank_ID and b==Bank_password and c==Employee_Name:
            print()
            print("WELCOME TO THE BANKING SYSTEM ",Employee_Name)
            print()
            while True:
                d=input("Please Enter 1 for Bank Details and 2 for Customer and 3 for Exit : ")
                if d=="1":
                    print("Bank ID : ",Bank_ID)
                    print("Bank Password : ",Bank_password)
                    print("Employee Name : ",Employee_Name)
                    print()
                elif d=="2":
                    self.customer()
                else:
                    print("Exit")
                    break  
        else:
            print("Information Not Match")
            print()
    def customer(self):
        import numpy as np
        print("1. for Enter Data")
        print("2. for Update Data")
        print("3. for Delete Data")
        print("4. for Show Data")
        print("5. for Exit")
        print()
        def Enter_Data():
            while True:
                press=input("Press Yes for Enter Data and Press No for exit : ")
                if press=="Yes":
                    customer_name=input("Enter customer name : ")
                    Mobile_Number=input("Enter customer Mobile Number: ")
                    Customer_Password=g.getpass("Enter your password : ")
                    customer_account_number=np.random.randint(1000000000,2000000000)
                    Balance=int(input("Please Enter your Balance: "))
                    print("Account Number Generated Successfully",customer_account_number)
                    self.CN.append(customer_name)
                    self.CM.append(Mobile_Number)
                    self.CP.append(Customer_Password)
                    self.CA.append(customer_account_number)
                    self.CB.append(Balance)
                    print()
                elif press=="No":
                    print()
                    break
                else:
                    print("wrong input")
                    print()
        def Update_Data():
            AC_NO=int(input("Enter account number : "))
            if AC_NO in self.CA:
                ind=self.CA.index(AC_NO)
                while True:
                    ud=input("1. for Name ,2. for Mobile ,3. for Password ,4. for Exit : ")
                    if ud=="1":
                        self.CN[ind]=input("Enter New Name : ")
                    elif ud=="2":
                        self.CM[ind]=input("Enter New Mobile Number : ")
                    elif ud=="3":
                        self.CP[ind]=input("Enter New Password : ")
                    else:
                        print("Exit")
                        print()
                        break
            else:
                print("wrong account number")
        def Delete_Data():
            while True:
                AC_NO=int(input("Enter account number or Exit(2) : "))
                if AC_NO in self.CA:
                    ind=self.CA.index(AC_NO)
                    del self.CN[ind]
                    del self.CM[ind]
                    del self.CP[ind]
                    del self.CA[ind]
                    del self.CB[ind]
                else:
                    print("wrong account number")
                    print()
                    break
        def Show_Data():
            while True:
                AC_NO=int(input("Enter account number or Exit(2) : "))
                if AC_NO in self.CA:
                    ind=self.CA.index(AC_NO)
                    print("Your Name : ",self.CN[ind])
                    print("Your Mobile Number : ",self.CM[ind])
                    print("Your Account No : ",self.CA[ind])
                    print("Your Balance : ",self.CB[ind])
                    print("Your Password : ",self.CP[ind])
                else:
                    print("sorry wrong account number")
                    print()
                    break
        while True:
            e=input("Press 1 for Enter Data, 2 for Update Data, 3 for delete Data, 4 for show data and 5 for exit : ")
            if e=="1":
                Enter_Data()
            elif e=="2":
                Update_Data()
            elif e=="3":
               Delete_Data()
            elif e=="4":
                Show_Data()
            else:
                break
    def customer_credit_debit(self,CA,CP,CM,CN,CB,indx):
        def credit_amount(CB,indx):
            credit=int(input("Enter credit amount : "))
            if credit>=1:
                CB[indx]+=credit
                print("Your Current Balance : ",CB[indx])
                print()
            else:
                print("Please Enter Valid Amount ")
                print()
            return CB
        def debit_amount(CB,indx):
            debit=int(input("Enter Debit Amount"))
            if debit<=CB[indx]:
                CB[indx]-=debit
                print("Your Current Amount : ",CB[indx])
                print()
            else:
                print("Not Enough Amount")
                print()
            return CB
        def show_Balance(CA,CP,CM,CN,CB,indx):
            print("Your Name             :",CN[indx])
            print("Your Account Number   :",CA[indx])
            print("Your Account PAsswrod :",CP[indx])
            print("Your Balance          :",CB[indx])
            print("Your Mobile Number    :",CM[indx])
            print()
        while True:
            print("1. for Credit Amount")
            print("2. for Debit Amount")
            print("3. for  Show Data")
            print("4. for Exit")
            xyz=int(input("Press a key : "))
            if xyz==1:
                credit_amount(CB,indx)
            elif xyz==2:
                debit_amount(CB,indx)
            elif xyz==3:
                show_Balance(CA,CP,CM,CN,CB,indx)
            else:
                print()
                break
##############################################################################################################################################################################################################################################################################################################################################################
print("Welcome")
bk=banking_system()
while True:
    a=input("Press 1 for Bank and 2 for Customer and 3 for Exit : ")
    if a=="1":
        bk.bank()
    elif a=="2":
        ca_no=int(input("Please Enter customer account number : "))
        c_p=g.getpass("Please Enter customer Password : ")
        indx=bk.CA.index(ca_no)
        indd=bk.CP.index(c_p)
        if bk.CA[indx]==ca_no:
            if bk.CP[indx]==c_p:
                bk.customer_credit_debit(bk.CA,bk.CP,bk.CM,bk.CN,bk.CB,indx)
            else:
                print("wrong password")
        else:
            print("Sorry, wrong account number")
    elif a=="3":
        break
    else:
        print("Wrong input")
print("Thanks for Visit")
# Out:
# Welcome
# Press 1 for Bank and 2 for Customer and 3 for Exit :  3
# Thanks for Visit
