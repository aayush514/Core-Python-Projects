# %% [markdown]
# ##### <font color="RED"><h1><b>Library Management System</b></h1></font>

# %%
class Library:
    import numpy as np
    def __init__(self):
        self.id = []
        self.n = []
        self.e = []
        self.p = []
        self.pn = []
        self.a = []
        self.bn= ["Tenali Rama","Mahabharat","400 Days","Harry Poter","Half Girlfriend"]
        self.bid= [54282,90547,23874,99024,89456]
        self.ba= ["C. L. L. Jayaprada","Vyasa","Chetan Bhagat","J. K. Rowling","Chetan Bhagat"]
        self.bamount = []
        self.ia = []
    def registration(self):
        email=input("\nEnter your Email ID : ")
        if email not in self.e:
            name=input("Please Enter your Name : ")
            ID=np.random.randint(10000,99999)
            password=input("Please Enter your Password : ")
            phone_number=int(input("Please Enter your Phone Number : "))
            Address=input("Enter your Address : ")
            print(f"Student ID Generate Successfully = {ID}")
            self.id.append(ID)
            self.n.append(name)
            self.p.append(password)
            self.e.append(email)
            self.pn.append(phone_number)
            self.a.append(Address)
            print()
        else:
            print("Email ID Already Exists!\n")

    def login(self):
        def update():
            while True:
                x=int(input("\nPress 1. Name , 2. Password , 3. Email ID , 4. Phone_Number , 5. Address"))
                if x==1:
                    self.n[ind]=input("Enter your New Name : ")
                elif x==2:
                    self.p[ind]=input("Enter your New Password : ")
                elif x==3:
                    self.e[ind]=input("Enter your new Email ID")
                elif x==4:
                    self.pn[ind]=int(input("Enter your new Phone Number"))
                elif x==5:
                    self.a[ind]=input("Enter New Address : ")
                else:
                    print("Exit")
                    break
        def delete():
            x=input("\nAre You Sure You Want To Delete Data (Yes/ NO) : ")
            if x=="Yes":
                del self.id[ind]
                del self.n[ind]
                del self.p[ind]
                del self.pn[ind]
                del self.e[ind]
                del self.a[ind]
                print("Data Delete Successfully")
            else:
                pass
        def show_data():
            x=int(input("Enter Student ID : "))
            if x in self.id:
                ind=self.id.index(x)
                print("Your Name : ",self.n[ind])
                print("Your Student ID : ",self.id[ind])
                print("Your Email ID : ",self.e[ind])
                print("Your Password : ",self.p[ind])
                print("Your Phone Number : ",self.pn[ind])
                print("Your Address : ",self.a[ind])
            else:
                print("No Data Found ")

        def book_available():
            x=int(input("\nPress 1 for Show Available Books & 2 for Add New Books : "))
            if x==1:
                for i in range(len(self.bid)):
                    print(f"Books {i+1}:")
                    print("\t Book ID = ",self.bid[i])
                    print("\t Book Name = ",self.bn[i])
                    print("\t Book Author = ",self.ba[i])
                    print()
            elif x==2:
                book_name=input("\nEnter Book Name : ")
                book_code=np.random.randint(10000,99999)
                book_author=input("Enter Book Author Name : ")
                self.bn.append(book_name)
                self.bid.append(book_code)
                self.ba.append(book_author)
                print()
            else:
                print("Exit\n")


        def purchase():
            bookid=int(input("Enter Book ID : "))
            if bookid in self.bid:
                indb=self.bid.index(bookid)
                print("\nBook Name : ",self.bn[indb])
                print("Book Code : ",self.bid[indb])
                print("Book Author : ",self.ba[indb])
                bookamount=np.random.randint(400,1000)
                print("Book Amount : ",bookamount)
                x=input("\nConfirm Yes to buy book or No to Cancel Transaction : ")
                if x=="Yes":
                    z=int(input("\nPress 1 for Paytm 2 for Card : "))
                    if z==1:
                        print("\nYou are Choosing Paytm")
                        upi=input("Enter Valid UPI ID : ")
                        upipin=int(input("Enter UPI PIN : "))
                        if upi=="100200300@paytm" and upipin==0000:
                            self.bamount.append(bookamount)
                            t=np.random.randint(10000000,99999999)
                            print("Your Transaction has been Successfull")
                            print("Your Transaction ID : ",t)
                            print()
                        else:
                            print("Incorrect UPI ID and UPI PIN")
                            print()
                        
                    elif z==2:
                        print("\nYou are Choosing Card Payment")
                        cardno=int(input("Enter Valid card No. : "))
                        cvv=int(input("Enter Card CVV"))
                        if cardno==123123123123 and cvv==420:
                            otp=np.random.randint(1000,9999)
                            print("Your OTP : ",otp)
                            OTP=int(input("Enter OTP"))
                            if OTP==otp:
                                self.bamount.append(bookamount)
                                t=np.random.randint(10000000,99999999)
                                print("Your Transaction has been Successfull")
                                print("Your Transaction ID : ",t)
                                print()
                            else:
                                print("Transaction Cancel")
                                print()
                        else:
                            print("Card Number Not Found")
                        
                        
                    else:
                        print("No Payment Method Found")
                else:
                    print("Payment Cancel Successfully")
            else:
                print("Please Enter Valid Book ID")
        def issue():
            x=int(input("\nEnter Book ID : "))
            if x in self.bid:
                ind=self.bid.index(x)
                print("\n BOOK FOUND")
                print("Book Name : ",self.bn[ind])
                print("Book Author Name : ",self.ba[ind])
                print("Book Code : ",self.bid[ind])
                issue_amount=np.random.randint(50,200)
                print("Issue Amount : ",issue_amount)
                x=input("\nConfirm Yes to Issue book or No to Cancel Issue : ")
                if x=="Yes":
                    z=int(input("\nPress 1 for Paytm 2 for Card : "))
                    if z==1:
                        print("\nYou are Choosing Paytm")
                        upi=input("Enter Valid UPI ID : ")
                        upipin=int(input("Enter UPI PIN : "))
                        if upi=="100200300@paytm" and upipin==0000:
                            self.ia.append(issue_amount)
                            t=np.random.randint(10000000,99999999)
                            print("Your Transaction has been Successfull")
                            print("Your Transaction ID : ",t)
                            print()
                        else:
                            print("Incorrect UPI ID and UPI PIN")
                            print()
                        
                    elif z==2:
                        print("\nYou are Choosing Card Payment")
                        cardno=int(input("Enter Valid card No. : "))
                        cvv=int(input("Enter Card CVV"))
                        if cardno==123123123123 and cvv==420:
                            otp=np.random.randint(1000,9999)
                            print("Your OTP : ",otp)
                            OTP=int(input("Enter OTP"))
                            if OTP==otp:
                                self.ia.append(issue_amount)
                                t=np.random.randint(10000000,99999999)
                                print("Your Transaction has been Successfull")
                                print("Your Transaction ID : ",t)
                                print()
                            else:
                                print("Transaction Cancel")
                                print()
                        else:
                            print("Card Number Not Found")
                    else:
                        print("No Payment Method Found")
                else:
                    print("Payment Cancel Successfully")

        def return_book():
            x=int(input("\nEnter Book ID : "))
            if x in self.bid:
                ind=self.bid.index(x)
                print(f"Your {self.ia[ind]} Amount will be credit in your account")
                del self.ia[ind]
                print("Book Return Successfully")
                print()
#######################################################################################################################################################################################################################                
        check_ID=int(input("Enter your Student ID : "))
        check_Password=input("Enter your Password : ")
        if check_ID in self.id and check_Password in self.p:
            ind=self.id.index(check_ID)
            while True:
                print("\nPress 1. Student Data")
                print("Press 2. Library Data")
                choice=int(input("\nPress a key : "))
                if choice==1:
                    while True:
                        print("\nPress 1. Update Data")
                        print("Press 2. Delete Data")
                        print("Press 3. Show Data")
                        uds=int(input("\nPress a key : "))
                        if uds==1:
                            update()
                        elif uds==2:
                            delete()
                        elif uds==3:
                            show_data()
                        else:
                            print("Exit")
                            break
                elif choice==2:
                    while True:
                        print("\nPress 1. Book Available")
                        print("Press 2. Purchase Book")
                        print("Press 3. Issue Book")
                        print("Press 4. Return Book")
                        bpir=int(input("\nPress a key : "))
                        if bpir==1:
                            book_available()
                        elif bpir==2:
                            purchase()
                        elif bpir==3:
                            issue()
                        elif bpir==4:
                            return_book()
                        else:
                            print("Exit")
                            break
                else:
                    print("Exit")
                    break
############################################################################################################################################################################################################################################
###########################################################################################################################################################################################################################################################################################################################################################################################################################
import getpass as g
import numpy as np
l=Library()
print("\t\t\t\t\t\t\tWelcome to the Library Management System")
LID=int(input("Please Enter your Library ID : "))
LP=g.getpass("Please Enter your Library Password : ")
if LID==123 and LP=="1111":
    while True:
        x=int(input("\nPress 1. Registation and Press 2. Login : "))
        if x==1:
            l.registration()
        elif x==2:
            l.login()
        elif x==3:
            print("Exit")
            break
        else:
            print("wrong Input")
else:
    print("Wrong ID and Password, Try Again Later!")
# Out:
# 							Welcome to the Library Management System
# Please Enter your Library ID :  1
# Please Enter your Library Password :  ········
# Wrong ID and Password, Try Again Later!
