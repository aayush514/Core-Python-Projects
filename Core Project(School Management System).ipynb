# %% [markdown]
# <font color="RED"><h1><b>SCHOOL MANAGEMENT SYSTEM</b></h1></font>

# %%
class School_System():
    def __init__(self):
        self.N= []
        self.M_N= []
        self.ID = []
        self.P = []
        self.S = []
        self.SJ = []
        self.SN = []
        self.SFN = []
        self.SMN = []
        self.SID = []
        self.SP = []
        self.SC = []
        self.SM_N = []
        self.SRN = []
        self.C = []
    def Enter_Data(self):
        def Teacher():
            def ADD_Data():
                Name=input("\nEnter Teacher Name : ")
                Mobile_Number=int(input("Enter Teacher Mobile Number : "))
                T_ID=np.random.randint(10000,99999)
                Password=g.getpass("Enter Teacher Password : ")
                Salary=int(input("Enter Salary : "))
                Subject=input("Enter Subject : ")
                print("TEACHER ID GENERATE SUCCESSFULLY : ",T_ID)
                self.N.append(Name)
                self.M_N.append(Mobile_Number)
                self.ID.append(T_ID)
                self.P.append(Password)
                self.S.append(Salary)
                self.SJ.append(Subject)
            def UPDATE_DATA():
                Teacher_ID=int(input("Enter Teacher ID : "))
                if Teacher_ID in self.ID:
                    ind=self.ID.index(Teacher_ID)
                    while True:
                        ud=int(input("\n1. for Name ,2. for Mobile ,3. for Password ,4. for Salary, 5. for Subject, 6. for Exit : "))
                        if ud==1:
                            self.N[ind]=input("Enter New Name : ")
                        elif ud==2:
                            self.M_N[ind]=input("Enter New Mobile Number : ")
                        elif ud==3:
                            self.P[ind]=g.getpass("Enter New Password : ")
                        elif ud==4:
                            self.S[ind]=input("Enter New Salary : ")
                        elif ud==5:
                            self.SJ[ind]=input("Enter New Subject")
                        else:
                            break
                else:
                    print("Wrong Teacher ID")
            def REMOVE_DATA():
                Teacher_ID=int(input("Enter Teacher_ID : "))
                if Teacher_ID in self.ID:
                    ind=self.ID.index(Teacher_ID)
                    del self.N[ind]
                    del self.M_N[ind]
                    del self.ID[ind]
                    del self.P[ind]
                    del self.S[ind]
                    del self.SJ[ind]
                    print("Data Delete Successfully")
                else:
                    print("Sorry wrong Teacher ID")
            def SHOW_DATA():
                Teacher_ID=int(input("\nEnter Teacher_ID : "))
                if Teacher_ID in self.ID:
                    ind=self.ID.index(Teacher_ID)
                    print("Teacher Name : ",self.N[ind])
                    print("Teacher Mobile Number : ",self.M_N[ind])
                    print("Teacher ID : ",self.ID[ind])
                    print("Teacher Password : ",self.P[ind])
                    print("Tecaher Salary : ",self.S[ind])
                    print("Teacher Subject : ",self.SJ[ind])
                else:
                    print("Sorry No Data Found\n")
            while True:
                print("\n1. Add Teacher Data")
                print("2. Update Teacher Data")
                print("3. Remove Teacher Data")
                print("4. Show Teacher Data")
                print("5. Exit")
                t=int(input("\nPress a key : "))
                if t==1:
                    ADD_Data()
                elif t==2:
                    UPDATE_DATA()
                elif t==3:
                    REMOVE_DATA()
                elif t==4:
                    SHOW_DATA()
                elif t==5:
                    break
                else:
                    print("Wrong Input")
        def Student():
            def ADD_STUDENT():
                Name=input("Enter Student Name : ")
                Father_Name=input("Enter Father Name : ") 
                Mother_Name=input("Enter Mother Name : ")
                Student_ID=np.random.randint(10000000,99999999)
                Student_Password=g.getpass("Enter Student Password")
                Class= input("Enter Class : ")
                Mob_No=int(input("Enter Mobile Number : "))
                Roll_No=np.random.randint(1,10)
                print("STUDENT ID GENERATE SUCCESSFULLY : ",Student_ID)
                self.SN.append(Name)
                self.SFN.append(Father_Name)
                self.SMN.append(Mother_Name)
                self.SID.append(Student_ID)
                self.SP.append(Student_Password)
                self.SC.append(Class)
                self.SM_N.append(Mob_No)
                self.SRN.append(Roll_No)
            def UPDATE_STUDENT():
                Student_ID=int(input("Enter Student ID : "))
                if Student_ID in self.SID:
                    ind=self.SID.index(Student_ID)
                    while True:
                        ud=int(input("\n1. for Name, 2. for Password, 3. for Class, 4. for Mobile Number, 5. for Roll NO, 6. for Exit : "))
                        if ud==1:
                            self.SN[ind]=input("Enter New Name : ")
                        elif ud==2:
                            self.SP[ind]=g.getpass("Enter New Password : ")
                        elif ud==3:
                            self.SC[ind]=input("Enter New Class : ")
                        elif ud==4:
                            self.SM_N[ind]=input("Enter New Mobile Number : ")
                        elif ud==5:
                            self.SRN[ind]=input("Enter New Roll Number : ")
                        else:
                            break
            def REMOVE_STUDENT():
                Student_ID=int(input("Enter Teacher_ID : "))
                if Student_ID in self.SID:
                    ind=self.SID.index(Student_ID)
                    del self.SN[ind]
                    del self.SFN[ind]
                    del self.SMN[ind]
                    del self.SID[ind]
                    del self.SP[ind]
                    del self.SC[ind]
                    del self.SM_N[ind]
                    del self.SRN[ind]
                    print("Data Delete Successfully")
                else:
                    print("Sorry wrong Teacher ID")
            def SHOW_STUDENT():
                Student_ID=int(input("Enter Teacher_ID : "))
                if Student_ID in self.SID:
                    ind=self.SID.index(Student_ID)
                    print("Student Name : ",self.SN[ind])
                    print("Student Father Name : ",self.SFN[ind])
                    print("Student Mother Name : ",self.SMN[ind])
                    print("Student ID : ",self.SID[ind])
                    print("Student Password : ",self.SP[ind])
                    print("Student Class : ",self.SC[ind])
                    print("Student Mobile Number : ",self.SM_N[ind])
                    print("Student Roll No. : ",self.SRN[ind])
                else:
                    print("Sorry No Data Found\n")
            while True:
                print("\n1. Add Student Data")
                print("2. Update Student Data")
                print("3. Remove Student Data")
                print("4. Show Student Data")
                print("5. Exit")
                s=int(input("\nPress a key : "))
                if s==1:
                    ADD_STUDENT()
                elif s==2:
                    UPDATE_STUDENT()
                elif s==3:
                    REMOVE_STUDENT()
                elif s==4:
                    SHOW_STUDENT()
                elif s==5:
                    break
                else:
                    print("Wrong Input")
        while True:
            x=int(input("\nPress 1 for Enter Teacher Data & Press 2 for Enter Student Data 3 for Exit : "))
            if x==1:
                Teacher()
            elif x==2:
                Student()
            else:
                break
    def Student_Grades_Data(self):
        def course_details():
            print()
            cd=input(" Enter Subject Name : ")
            if cd in self.SJ:
                indd=self.SJ.index(cd)
                print("Teacher Name : ",self.N[indd])
                print("Teacher Subject : ",self.SJ[indd])
                print("Teacher ID : ",self.ID[indd])
                print("Teacher Mobile Number : ",self.M_N[indd])
            else:
                print(f"Sorry We Don't have Teacher for {cd} Subject")
        def student_course_data():
            print()
            while True:
                scd=int(input("Press 1 for ADD Student Course & 2 for Remove Student Course & 3 for Show Student Course"))
                if scd==1:
                    scd2=int(input("Enter Student ID for ADD Course Data : "))
                    if scd2 in self.SID:
                        indd=self.SID.index(scd2)
                        Course=input("Enter Subject Name : ")
                        self.C.append(Course)
                        print(f"{Course} Course Added Successfully : ")
                        print()
                    else:
                        print("Wrong Student ID\n")
                elif scd==2:
                    scd2=int(input("Enter Student ID for Remove Course Data : "))
                    if scd2 in self.SID:
                        indd=self.SID.index(scd2)
                        del self.C[indd]
                    else:
                        print("Wrong Student ID\n")
                elif scd==3:
                    scd2=int(input("Enter Student ID for Show Course Data : "))
                    if scd2 in self.SID:
                        indd=self.SID.index(scd2)
                        print("Student Name : ",self.SN[indd])
                        print("Student ID : ",self.SID[indd])
                        print("Student Course : ",self.C[indd])
                    else:
                        print("wrong Student ID\n")
                else:
                    break               
        def check_score_data():
            csd=int(input("Enter Student ID for Check Course Data : "))
            if csd in self.SID:
                indd=self.SID.index(csd)
                marks=np.random.randint(10,100)
                print("Student Name : ",self.SN[indd])
                print(f"Student Marks in {self.C[indd]} Subject is {marks}")
                if marks >=33:
                    print("STUDENT PASS")
                else:
                    print("STDENT FAIL")
        while True:
            print()
            print("1. Course Details")
            print("2. Student Course Data")
            print("3. Check Score Data")
            print("4. Exit")
            sgd=int(input("Press a key : "))
            if sgd==1:
                course_details()
            elif sgd==2:
                student_course_data()
            elif sgd==3:
                check_score_data()
            elif sgd==4:
                break
            else:
                print("wrong input")

##########################################################################################################################################################################################################################################################################################################################################################
import numpy as np
import getpass as g
ss=School_System()
print("\t\t\t\t                  WELCOME TO SCHOOL MANAGEMENT SYSTEM")
print("Please Enter Your School ID & School Passsword")
School_ID=int(input("Enter School ID : "))
School_Password=int(g.getpass("Enter School Password : "))
if School_ID==123123 and School_Password==123:
    print()
    while True:
        a=int(input("Press 1 for Enter Data & 2 for Student Grades Data & 3 for Exit : "))
        if a==1:
            ss.Enter_Data()
        elif a==2:
            ss.Student_Grades_Data()
        else:
            break
else:
    print("Wrong ID and Password")
print("Thanks")
# Out:
# 				                  WELCOME TO SCHOOL MANAGEMENT SYSTEM
# Please Enter Your School ID & School Passsword
# Enter School ID :  123123
# Enter School Password :  ········
# Press 1 for Enter Data & 2 for Student Grades Data & 3 for Exit :  3
# Thanks
