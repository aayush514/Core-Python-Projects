# %% [markdown]
# <font color="RED"><h1><b>TASK MANAGEMENT SYSTEM</b></h1></font>

# %%
class Task:
    def __init__(self):
        self.name=[]
        self.email=[]
        self.password=[]
        self.w_title=[]
        self.w_date=[]
        self.w_about_title=[]
        self.w_written_by=[]
        self.p_title=[]
        self.p_date=[]
        self.p_about_title=[]
        self.p_written_by=[]
        self.s_title=[]
        self.s_date=[]
        self.s_about_title=[]
        self.s_written_by=[]
    def Signup(self):
        email=input("Enter your Email ID : ")
        if email not in self.email:
            name=input("Enter your Good Name : ")
            password=input("Enter your password : ")
            self.name.append(name)
            self.password.append(password)
            self.email.append(email)
            print("Signup Successfully!")
            print()
        else:
            print("Email-ID already Found!")
            print()
    def Login(self):
        def w_create():
            try:
                from datetime import date
                print()
                title=input("Please Enter Title about Your Task : ")
                date=date.today()
                about_title=input("Please Enter data About your Title : ")
                written_by=input("Please Enter Author Name : ")
                self.w_title.append(title)
                self.w_date.append(date)
                self.w_about_title.append(about_title)
                self.w_written_by.append(written_by)
                print()
            except:
                print("Please Fill All Credential Correctly!")
                print()
        def w_update():
            from datetime import date, datetime
            x=input("Enter the date of the task you want to update (%YYYY%-%MM%-%DD%): ")
            print()
            try:
                y=datetime.strptime(x,"%Y-%m-%d").date()
            except ValueError:
                print("Invalid date format! Please enter the date in YYYY-MM-DD format.")
                print()
                return
            if y in self.w_date:
                ind=self.w_date.index(y)
                title=input("Please Enter Title Name : ")
                if title in self.w_title:
                    inda=self.w_title.index(title)
                    from datetime import date
                    date=date.today()
                    self.w_date[inda]=date
                    print()
                    print(f"Current Details for your task on {x} ")
                    print(f"Title : {self.w_title[inda]}")
                    print(f"Data About Your Title : {self.w_about_title[inda]}")
                    print(f"Written By : {self.w_written_by[inda]}")
                    print()
                    while True:
                        print("What do you Want to Update : ")
                        print("Press 1 for Title")
                        print("Press 2 for About_Title")
                        print("Press 3 for Written_by")
                        print()
                        a=int(input("Press a key : "))
                        if a==1:
                            title=input("Enter New Title : ")
                            self.w_title[inda]=title
                            print()
                        elif a==2:
                            about_title=input("Enter New Data about your Title : ")
                            self.w_about_title[inda]=about_title
                            print()
                        elif a==3:
                            written_by=input("Enter New Author Name")
                            self.w_written_by[inda]=written_by
                            print()
                        else:
                            print("Exit")
                            print()
                            break
                else:
                    print("No title Found!")
            else:
                print("No Date Found!")
        def w_delete():
            from datetime import date, datetime
            x=input("Enter the date of the task you want to update (%YYYY%-%MM%-%DD%): ")
            print()
            try:
                y=datetime.strptime(x,"%Y-%m-%d").date()
            except ValueError:
                print("Invalid date format! Please enter the date in YYYY-MM-DD format.")
                print()
                return
            if y in self.w_date:
                ind=self.w_date.index(y)
                title=input("Please Enter Title Name : ")
                if title in self.w_title:
                    inda=self.w_title.index(title)
                    del self.w_title[inda]
                    del self.w_about_title[inda]
                    del self.w_date[inda]
                    del self.w_written_by[inda]
                    print("Task delete successfully")
                    print()
                else:
                    print("No title Found!")
                    print()
            else:
                print("No Date Found!")
                print()
        def w_show():
            print()
            for i in range(len(self.w_title)):
                print(f"Task Info. {i+1}:")
                print("\t Title    = ",self.w_title[i])
                print("\t date  = ",self.w_date[i])
                print("\t About Title = ",self.w_about_title[i])
                print("\t Written By = ",self.w_written_by[i])
                print()
        def p_create():
            try:
                from datetime import date
                print()
                title=input("Please Enter Title about Your Task : ")
                date=date.today()
                about_title=input("Please Enter data About your Title : ")
                written_by=input("Please Enter Author Name : ")
                self.p_title.append(title)
                self.p_date.append(date)
                self.p_about_title.append(about_title)
                self.p_written_by.append(written_by)
                print()
            except:
                print("Please Fill All Credential Correctly!")
                print()
        def p_update():
            from datetime import date, datetime
            x=input("Enter the date of the task you want to update (%YYYY%-%MM%-%DD%): ")
            print()
            try:
                y=datetime.strptime(x,"%Y-%m-%d").date()
            except ValueError:
                print("Invalid date format! Please enter the date in YYYY-MM-DD format.")
                print()
                return
            if y in self.p_date:
                ind=self.p_date.index(y)
                title=input("Please Enter Title Name : ")
                if title in self.p_title:
                    inda=self.p_title.index(title)
                    from datetime import date
                    date=date.today()
                    self.p_date[inda]=date
                    print()
                    print(f"Current Details for your task on {x} ")
                    print(f"Title : {self.p_title[inda]}")
                    print(f"Data About Your Title : {self.p_about_title[inda]}")
                    print(f"Written By : {self.p_written_by[inda]}")
                    print()
                    while True:
                        print("What do you Want to Update : ")
                        print("Press 1 for Title")
                        print("Press 2 for About_Title")
                        print("Press 3 for Written_by")
                        print()
                        a=int(input("Press a key : "))
                        if a==1:
                            title=input("Enter New Title : ")
                            self.p_title[inda]=title
                            print()
                        elif a==2:
                            about_title=input("Enter New Data about your Title : ")
                            self.p_about_title[inda]=about_title
                            print()
                        elif a==3:
                            written_by=input("Enter New Author Name")
                            self.p_written_by[inda]=written_by
                            print()
                        else:
                            print("Exit")
                            print()
                            break
                else:
                    print("No title Found!")
            else:
                print("No Date Found!")
        def p_delete():
            from datetime import date, datetime
            x=input("Enter the date of the task you want to update (%YYYY%-%MM%-%DD%): ")
            print()
            try:
                y=datetime.strptime(x,"%Y-%m-%d").date()
            except ValueError:
                print("Invalid date format! Please enter the date in YYYY-MM-DD format.")
                print()
                return
            if y in self.p_date:
                ind=self.p_date.index(y)
                title=input("Please Enter Title Name : ")
                if title in self.p_title:
                    inda=self.p_title.index(title)
                    del self.p_title[inda]
                    del self.p_about_title[inda]
                    del self.p_date[inda]
                    del self.p_written_by[inda]
                    print("Task delete successfully")
                    print()
                else:
                    print("No title Found!")
                    print()
            else:
                print("No Date Found!")
                print()
        def p_show():
            print()
            for i in range(len(self.p_title)):
                print(f"Task Info. {i+1}:")
                print("\t Title    = ",self.p_title[i])
                print("\t date  = ",self.p_date[i])
                print("\t About Title = ",self.p_about_title[i])
                print("\t Written By = ",self.p_written_by[i])
                print()
        def s_create():
            try:
                from datetime import date
                print()
                title=input("Please Enter Title about Your Task : ")
                date=date.today()
                about_title=input("Please Enter data About your Title : ")
                written_by=input("Please Enter Author Name : ")
                self.s_title.append(title)
                self.s_date.append(date)
                self.s_about_title.append(about_title)
                self.s_written_by.append(written_by)
                print()
            except:
                print("Please Fill All Credential Correctly!")
                print()
        def s_update():
            from datetime import date, datetime
            x=input("Enter the date of the task you want to update (%YYYY%-%MM%-%DD%): ")
            print()
            try:
                y=datetime.strptime(x,"%Y-%m-%d").date()
            except ValueError:
                print("Invalid date format! Please enter the date in YYYY-MM-DD format.")
                print()
                return
            if y in self.s_date:
                ind=self.s_date.index(y)
                title=input("Please Enter Title Name : ")
                if title in self.s_title:
                    inda=self.s_title.index(title)
                    from datetime import date
                    date=date.today()
                    self.s_date[inda]=date
                    print()
                    print(f"Current Details for your task on {x} ")
                    print(f"Title : {self.s_title[inda]}")
                    print(f"Data About Your Title : {self.s_about_title[inda]}")
                    print(f"Written By : {self.s_written_by[inda]}")
                    print()
                    while True:
                        print("What do you Want to Update : ")
                        print("Press 1 for Title")
                        print("Press 2 for About_Title")
                        print("Press 3 for Written_by")
                        print()
                        a=int(input("Press a key : "))
                        if a==1:
                            title=input("Enter New Title : ")
                            self.s_title[inda]=title
                            print()
                        elif a==2:
                            about_title=input("Enter New Data about your Title : ")
                            self.s_about_title[inda]=about_title
                            print()
                        elif a==3:
                            written_by=input("Enter New Author Name")
                            self.s_written_by[inda]=written_by
                            print()
                        else:
                            print("Exit")
                            print()
                            break
                else:
                    print("No title Found!")
            else:
                print("No Date Found!")
        def s_delete():
            from datetime import date, datetime
            x=input("Enter the date of the task you want to update (%YYYY%-%MM%-%DD%): ")
            print()
            try:
                y=datetime.strptime(x,"%Y-%m-%d").date()
            except ValueError:
                print("Invalid date format! Please enter the date in YYYY-MM-DD format.")
                print()
                return
            if y in self.s_date:
                ind=self.s_date.index(y)
                title=input("Please Enter Title Name : ")
                if title in self.s_title:
                    inda=self.s_title.index(title)
                    del self.s_title[inda]
                    del self.s_about_title[inda]
                    del self.s_date[inda]
                    del self.s_written_by[inda]
                    print("Task delete successfully")
                    print()
                else:
                    print("No title Found!")
                    print()
            else:
                print("No Date Found!")
                print()
        def s_show():
            print()
            for i in range(len(self.s_title)):
                print(f"Task Info. {i+1}:")
                print("\t Title    = ",self.s_title[i])
                print("\t date  = ",self.s_date[i])
                print("\t About Title = ",self.s_about_title[i])
                print("\t Written By = ",self.s_written_by[i])
                print()
        print()
        email=input("Enter your Email ID : ")
        if email in self.email:
            ind=self.email.index(email)
            password=input("Enter your password : ")
            if password==self.password[ind]:
                print("What is your purpose for Task Management System?")
                print()
                while True:
                    print()
                    x=input("For Work , For Personal Use , For Shopping List ")
                    if x=="Work" or x=="work":
                        while True:
                            print()
                            print("Press 1 for Create")
                            print("Press 2 for Update")
                            print("Press 3 for Delete")
                            print("Press 4 for Show Data")
                            print("Press 5 for Exit")
                            print()
                            x=int(input("Press a key : "))
                            if x==1:
                                w_create()
                            elif x==2:
                                w_update()
                            elif x==3:
                                w_delete()
                            elif x==4:
                                w_show()
                            elif x==5:
                                break
                            else:
                                print("Wrong Input")
                                print()
                    elif x=="Personal Use" or x=="personal use":
                        while True:
                            print()
                            print("Press 1 for Create")
                            print("Press 2 for Update")
                            print("Press 3 for Delete")
                            print("Press 4 for Show Data")
                            print("Press 5 for Exit")
                            print()
                            x=int(input("Press a key : "))
                            if x==1:
                                p_create()
                            elif x==2:
                                p_update()
                            elif x==3:
                                p_delete()
                            elif x==4:
                                p_show()
                            elif x==5:
                                break
                            else:
                                print("Wrong Input")
                                print()
                    elif x=="Shopping List" or x=="shopping list" or x=="Shopping list":
                        while True:
                            print()
                            print("Press 1 for Create")
                            print("Press 2 for Update")
                            print("Press 3 for Delete")
                            print("Press 4 for Show Data")
                            print("Press 5 for Exit")
                            print()
                            x=int(input("Press a key : "))
                            if x==1:
                                s_create()
                            elif x==2:
                                s_update()
                            elif x==3:
                                s_delete()
                            elif x==4:
                                s_show()
                            elif x==5:
                                break
                            else:
                                print("Wrong Input")
                                print()
                    else:
                        print("Its Okey, You can add Field Anytime!")
                        break
            else:
                print("Wrong Password")
                print()
        else:
            print("No Records Found!")
            print()
#########################################################################################################################################################################################################################################################################
import getpass as g
t=Task()
print("\t\t\t\t\t\tWelcome to to Task Management System")
while True:
    print("\nPress 1 for Signup")
    print("Press 2 for Login")
    print("Press 3 for Exit!\n")
    x=int(input("Press a Key : "))
    if x==1:
        t.Signup()
    elif x==2:
        t.Login()
    elif x==3:
        print("Thanks")
        break
    else:
        print("Wrong Input")
# Out:
# 						Welcome to to Task Management System
#
# Press 1 for Signup
# Press 2 for Login
# Press 3 for Exit!
# Press a Key :  3
# Thanks
